# %%
import sys
print(sys.version)
# Out:
# 3.8.15 (default, Oct 12 2022, 19:14:39)
# [GCC 7.5.0]

# %% [markdown]
# # library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
